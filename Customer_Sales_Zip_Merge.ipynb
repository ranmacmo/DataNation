# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io

# %%
# Load the customer dataset
file_path = "data/Customer_sales.csv"
df_customer_sales = pd.read_csv(file_path,dtype={"BillPostalCode":"string"} )
df_customer_sales
# Out:
#         CustomerID BillPostalCode BillStateProvCode BillCountryCode      LOB  \
# 0            10012          49649                MI              US  Salvage
# 1            10012          49649                MI              US  Salvage
# 2            10012          49649                MI              US  Salvage
# 3            10012          49649                MI              US  Salvage
# 4            24012          68713                NE              US  Salvage
# ...            ...            ...               ...             ...      ...
# 237096   374531012          70578                LA              US  Salvage
# 237097   374532012          54758                WI              US  Salvage
# 237098   374533012          77868                TX              US  Salvage
# 237099   374534012          47933                IN              US  Salvage
# 237100   374535012          61275                IL              US  Salvage
#
# ...

# %%
# Load zipcode dataset and ensure that zipcodes are read as strings
file_path = "data/USZip_info.csv"
df_zipcodes= pd.read_csv(file_path,dtype={"zip":"string"})
df_zipcodes.head(10)
# Out:
#      zip       lat       lng         city state_id   state_name  zcta  \
# 0  00601  18.18004 -66.75218     Adjuntas       PR  Puerto Rico  True
# 1  00602  18.36073 -67.17517       Aguada       PR  Puerto Rico  True
# 2  00603  18.45439 -67.12202    Aguadilla       PR  Puerto Rico  True
# 3  00606  18.16724 -66.93828      Maricao       PR  Puerto Rico  True
# 4  00610  18.29032 -67.12243       Anasco       PR  Puerto Rico  True
# 5  00612  18.40699 -66.70803      Arecibo       PR  Puerto Rico  True
# 6  00616  18.41753 -66.66814     Bajadero       PR  Puerto Rico  True
# 7  00617  18.44124 -66.55917  Barceloneta       PR  Puerto Rico  True
# 8  00622  17.99174 -67.15248     Boqueron       PR  Puerto Rico  True
# 9  00623  18.08355 -67.15417    Cabo Rojo       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips  county_name  \
# 0          NaN       17242    111.4        72001     Adjuntas
# 1          NaN       38442    523.5        72003       Aguada
# ...

# %%
df_customer_sale_demographics  = pd.merge(df_customer_sales, df_zipcodes, left_on='BillPostalCode', right_on='zip')
df_customer_sale_demographics
# Out:
#         CustomerID BillPostalCode BillStateProvCode BillCountryCode  \
# 0            10012          49649                MI              US
# 1            10012          49649                MI              US
# 2            10012          49649                MI              US
# 3            10012          49649                MI              US
# 4        240859012          49649                MI              US
# ...            ...            ...               ...             ...
# 235065   374494012          42151                KY              US
# 235066   374494012          42151                KY              US
# 235067   374523012          54616                WI              US
# 235068   374523012          54616                WI              US
# 235069   374529012          58630                ND              US
#
#                       LOB Market  ChannelOrderID   OrderDate  Quantity  \
# 0                 Salvage   eBay         4468548  2021-04-29         1
# ...

# %%
df_customer_sale_demographics.groupby("CustomerID")
