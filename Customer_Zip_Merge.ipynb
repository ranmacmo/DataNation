# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io

# %%
# Load the customer dataset
file_path = "data/Customer_data_merged.csv"
df_customer_merge = pd.read_csv(file_path,dtype={"BillPostalCode":"string"} )
df_customer_merge
# Out:
#         CustomerID ZipCode State  ArticCat_Tot  Bobcat_Tot  Can-Am_Tot  \
# 0            10012   49649    MI           0.0         0.0      121.98
# 1            24012   68713    NE           0.0         0.0      590.97
# 2            36012   54460    WI           0.0         0.0        0.00
# 3            48012   91331    CA           0.0         0.0      499.93
# 4            49012   52070    IA           0.0         0.0        0.00
# ...            ...     ...   ...           ...         ...         ...
# 141456   375213012   68701    NE           0.0         0.0        0.00
# 141457   375214012   70094    LA           0.0         0.0        0.00
# 141458   375215012   77990    TX           0.0         0.0        0.00
# 141459   375216012   42437    KY           0.0         0.0        0.00
# 141460   375217012   36116    AL           0.0         0.0        0.00
#
#         Honda_Tot  John-Deere_Tot  Kawasaki_Tot  Kubota_Tot  ...  \
# ...

# %%
# Load zipcode dataset and ensure that zipcodes are read as strings
file_path = "data/USZip_info.csv"
df_zipcodes= pd.read_csv(file_path,dtype={"zip":"string"})
df_zipcodes
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0      00601  18.18004  -66.75218     Adjuntas       PR  Puerto Rico  True
# 1      00602  18.36073  -67.17517       Aguada       PR  Puerto Rico  True
# 2      00603  18.45439  -67.12202    Aguadilla       PR  Puerto Rico  True
# 3      00606  18.16724  -66.93828      Maricao       PR  Puerto Rico  True
# 4      00610  18.29032  -67.12243       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33094  99923  55.97796 -130.03671        Hyder       AK       Alaska  True
# 33095  99925  55.55767 -132.97627      Klawock       AK       Alaska  True
# 33096  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33097  99927  56.25100 -133.37571  Point Baker       AK       Alaska  True
# 33098  99929  56.36950 -131.93648     Wrangell       AK       Alaska  True
#
# ...

# %%
df_customer_demographics  = pd.merge(df_customer_merge, df_zipcodes, left_on='ZipCode', right_on='zip', how='left')
df_customer_demographics
# Out:
#         CustomerID ZipCode State  ArticCat_Tot  Bobcat_Tot  Can-Am_Tot  \
# 0            10012   49649    MI           0.0         0.0      121.98
# 1            24012   68713    NE           0.0         0.0      590.97
# 2            36012   54460    WI           0.0         0.0        0.00
# 3            48012   91331    CA           0.0         0.0      499.93
# 4            49012   52070    IA           0.0         0.0        0.00
# ...            ...     ...   ...           ...         ...         ...
# 141456   375213012   68701    NE           0.0         0.0        0.00
# 141457   375214012   70094    LA           0.0         0.0        0.00
# 141458   375215012   77990    TX           0.0         0.0        0.00
# 141459   375216012   42437    KY           0.0         0.0        0.00
# 141460   375217012   36116    AL           0.0         0.0        0.00
#
#         Honda_Tot  John-Deere_Tot  Kawasaki_Tot  Kubota_Tot  ...  population  \
# ...

# %%
df_customer_demographics[pd.isnull(df_customer_demographics['zip'])]
# Out:
#         CustomerID ZipCode State  ArticCat_Tot  Bobcat_Tot  Can-Am_Tot  \
# 225        2494012   19481    PA          0.00         0.0        0.00
# 276        3344012   33195    FL          0.00         0.0        0.00
# 299        3754012   77626    TX        213.97         0.0      999.99
# 488        6690012   76202    TX         93.98         0.0      184.99
# 566        8157012   33198    FL          0.00         0.0        0.00
# ...            ...     ...   ...           ...         ...         ...
# 140647   374361012   33195    FL          0.00         0.0        0.00
# 140709   374426012   33195    FL          0.00         0.0        0.00
# 140767   374485012   33195    FL          0.00         0.0        0.00
# 141223   374970012   33195    FL          0.00         0.0        0.00
# 141298   375047012   33195    FL          0.00         0.0        0.00
#
#         Honda_Tot  John-Deere_Tot  Kawasaki_Tot  Kubota_Tot  ...  population  \
# ...

# %%
df_customer_sale_demographics
# Out:
#         CustomerID BillPostalCode BillStateProvCode    zip       lat  \
# 0            10012          49649                MI  49649  44.56776
# 1            24012          68713                NE  68713  42.53794
# 2            36012          54460                WI  54460  44.94244
# 3            48012          91331                CA  91331  34.25563
# 4            49012          52070                IA  52070  42.08160
# ...            ...            ...               ...    ...       ...
# 141456   375213012          68701                NE  68701  42.02136
# 141457   375214012          70094                LA  70094  29.91347
# 141458   375215012          77990                TX  77990  28.46992
# 141459   375216012          42437                KY  42437  37.66397
# 141460   375217012          36116                AL  36116  32.27263
#
#               lng         city state_id  state_name  zcta  ...  population  \
# ...
